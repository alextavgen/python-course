# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  
# %pylab inline
pylab.rcParams['figure.figsize'] = (80, 80)
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from influxdb import InfluxDBClient
from influxdb import DataFrameClient
client = InfluxDBClient('167.71.79.231', 8086, 'admin', '', 'timetrix')

# %%
result = client.query('SELECT * FROM "smart_home" WHERE "location"=\'Tallinn\' AND time>=1569888000s AND time<=1574294400s;')

# %%
df= pd.DataFrame(result.get_points())
df
# Out:
#                              time  city location  room sensor  \
# 0        2019-10-01T00:00:07.557Z  None  Tallinn  None   None
# 1        2019-10-01T00:00:07.557Z  None  Tallinn  None   None
# 2        2019-10-01T00:00:07.557Z  None  Tallinn  None   None
# 3        2019-10-01T00:00:07.557Z  None  Tallinn  None   None
# 4        2019-10-01T00:00:07.557Z  None  Tallinn  None   None
# ...                           ...   ...      ...   ...    ...
# 1167507  2019-11-20T23:59:31.938Z  None  Tallinn  None   None
# 1167508  2019-11-20T23:59:31.938Z  None  Tallinn  None   None
# 1167509  2019-11-20T23:59:31.938Z  None  Tallinn  None   None
# 1167510  2019-11-20T23:59:31.938Z  None  Tallinn  None   None
# 1167511  2019-11-20T23:59:31.938Z  None  Tallinn  None   None
#
#                                   type   value
# 0                        ambient_light  989.00
# 1        temperature_digital_farenheit   82.22
# 2                   heit_index_celsium   28.09
# ...

# %%
df[df['type']=='quality']
# Out:
#                              time  city location  room sensor     type  value
# 4        2019-10-01T00:00:07.557Z  None  Tallinn  None   None  quality   56.0
# 15       2019-10-01T00:00:37.621Z  None  Tallinn  None   None  quality   56.0
# 17       2019-10-01T00:01:07.683Z  None  Tallinn  None   None  quality   56.0
# 28       2019-10-01T00:01:37.747Z  None  Tallinn  None   None  quality   56.0
# 39       2019-10-01T00:02:07.811Z  None  Tallinn  None   None  quality   56.0
# ...                           ...   ...      ...   ...    ...      ...    ...
# 1167473   2019-11-20T23:57:31.63Z  None  Tallinn  None   None  quality   98.0
# 1167484  2019-11-20T23:58:01.719Z  None  Tallinn  None   None  quality   98.0
# 1167495   2019-11-20T23:58:31.79Z  None  Tallinn  None   None  quality   97.0
# 1167497   2019-11-20T23:59:01.86Z  None  Tallinn  None   None  quality   97.0
# 1167508  2019-11-20T23:59:31.938Z  None  Tallinn  None   None  quality   97.0
#
# [145939 rows x 7 columns]

# %%
quality = df[df['type']=='quality']

# %%
quality['value'].plot()

# %%
pylab.rcParams['figure.figsize'] = (80, 80)

# %%
quality['value'].plot()
